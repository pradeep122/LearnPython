# %%
import pandas as pd
df = pd.read_csv('ecsv_1_2018.csv')
for  1qsaqsZdf
# Out:
#        InvoiceID  PayerAccountId  LinkedAccountId      RecordType  \
# 0    126084499.0    109020781296              NaN   PayerLineItem
# 1    126084499.0    109020781296              NaN   PayerLineItem
# 2    126084499.0    109020781296              NaN   PayerLineItem
# 3    126084499.0    109020781296              NaN   PayerLineItem
# 4    126084499.0    109020781296              NaN   PayerLineItem
# 5    126084499.0    109020781296              NaN   PayerLineItem
# 6    126084499.0    109020781296              NaN   PayerLineItem
# 7    126084499.0    109020781296              NaN   PayerLineItem
# 8    126084499.0    109020781296              NaN   PayerLineItem
# 9    126084499.0    109020781296              NaN   PayerLineItem
# 10   126084499.0    109020781296              NaN   PayerLineItem
# 11   126084499.0    109020781296              NaN   PayerLineItem
# 12   126084499.0    109020781296              NaN   PayerLineItem
# ...

# %%
df.shape
# Out:
# (232, 29)

# %%
df.describe()
# Out:
#          InvoiceID  PayerAccountId  LinkedAccountId  PayerPONumber  \
# count        229.0    2.320000e+02     1.160000e+02            0.0
# mean   126084499.0    1.090208e+11     2.971329e+11            NaN
# std            0.0    0.000000e+00     3.515050e+11            NaN
# min    126084499.0    1.090208e+11     1.090208e+11            NaN
# 25%    126084499.0    1.090208e+11     1.090208e+11            NaN
# 50%    126084499.0    1.090208e+11     1.090208e+11            NaN
# 75%    126084499.0    1.090208e+11     1.090208e+11            NaN
# max    126084499.0    1.090208e+11     9.482904e+11            NaN
#
#              RateId  UsageQuantity  BlendedRate  CostBeforeTax  Credits  \
# count  2.270000e+02   2.270000e+02   114.000000     232.000000    231.0
# mean   2.195174e+08   1.025726e+05     0.036536      16.289344      0.0
# std    3.488423e+07   9.632875e+05     0.102859      88.748929      0.0
# min    4.669909e+06   2.000000e-08     0.000000       0.000000      0.0
# ...

# %%
df.values
# Out:
# array([[126084499.0, 109020781296, nan, ..., 0.0, 'None', 0.01],
#        [126084499.0, 109020781296, nan, ..., 0.0, 'None', 0.0],
#        [126084499.0, 109020781296, nan, ..., 0.0, 'None', 0.0],
#        ...,
#        [nan, 109020781296, 109020781296.0, ..., 0.0, nan, 730.9892],
#        [nan, 109020781296, 948290371180.0, ..., 4.44, nan,
#         29.098633000000003],
#        [nan, 109020781296, nan, ..., 4.44, nan, 760.31]], dtype=object)
